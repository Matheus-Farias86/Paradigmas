# %%
# Metodo para calcular valor do desconto
def calc_desconto(preco, desconto):
  val = preco * desconto / 100
  return val

# %%
# Metodo para calcular o valor apagar
def calc_apagar(preco, val):
  a_pagar = preco - val
  return a_pagar

# %%
entrada_dados()

a = calc_desconto(preco, desconto)
b = calc_apagar(preco, a)

imprimir(preco, desconto, a, b)
# Out:
# Digite o preço da mercadoria: 100
# Digite o percentual de desconto: 14
# Um desconto de  5.00 % em  uma mercadoria de R$  100.00
# vale R$    5.00.
# O valor a pagar é de R$   95.00

# %%
def imprimir(preco, desconto, a, b):
  print("Um desconto de %5.2f %% em  uma mercadoria de R$ %7.2f" % (desconto,preco))
  print("vale R$ %7.2f." % a)
  print("O valor a pagar é de R$ %7.2f" % b)

# %%
def entrada_dados():
  preco = float(input("Digite o preço da mercadoria: "))
  desconto = float(input("Digite o percentual de desconto: "))
